# %% [markdown]
# # `Word2Vec`

# %%
import nltk
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %% [markdown]
# #### Vamos utilizar um texto de uma página do Wikipedia

# %% [markdown]
# https://pt.wikipedia.org/wiki/Monarquia_do_Reino_Unido
#
#
# A monarquia do Reino Unido, comumente chamada de monarquia britânica, é a monarquia constitucional do Reino Unido e seus territórios ultramarinos. O título do monarca é "rei" (homem) ou "rainha" (mulher). O atual monarca é Carlos III, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, Isabel II.
#
# O monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o Parlamento e dissolve-lo. Como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro. O monarca é tradicionalmente comandante em chefe das Forças Armadas Britânicas. Apesar da última autoridade formal executiva do governo do Reino Unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.
#
# A monarquia britânica traça suas origens nos pequenos reinos da Escócia na alta idade média e os da Inglaterra anglo-saxã, que consolidaram-se nos reinos da Inglaterra e Escócia por volta do século X. O último monarca anglo-saxão, Haroldo II, foi derrotado e morto em 1066 durante a conquista normanda da Inglaterra e assim a monarquia inglesa passou para o normando Guilherme, o Conquistador, e seus descendentes.
#
# O norte do País de Gales, como principado, virou um estado cliente da Inglaterra no século XIII, enquanto a Magna Carta começou um processo de reduzir os poderes políticos do monarca.
#
# Os reinos da Inglaterra e Escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei Jaime VI da Escócia herdou o trono inglês como Jaime I. De 1649 a 1660, a tradição da monarquia foi quebrada pela republicana Comunidade da Inglaterra, que estabeleceu-se depois da Guerra Civil Inglesa. O Decreto de Estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão. Os reinos da Inglaterra e Escócia foram unidos em 1707 no Reino da Grã-Bretanha, e em 1801 o Reino da Irlanda se uniu para criar o Reino Unido da Grã-Bretanha e Irlanda. O monarca britânico tornou-se o chefe nominal do vasto Império Britânico, que cobriu um quarto da superfície da Terra em sua maior extensão no ano de 1921.
#
# A maior parte da Irlanda separou-se da união na década de 1920 como o Estado Livre Irlandês, com a Declaração Balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro Commonwealth. Depois da Segunda Guerra Mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império. Jorge VI e sua sucessora Isabel II adotaram o título de Chefe da Comunidade Britânica como símbolo da livre associação de estados independentes.
#
# O Reino Unido e quinze outras monarquias da Commonwealth partilham a mesma pessoa como seu monarca e são chamados de Reinos da Comunidade de Nações. Os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino.

# %%
text = """A monarquia do Reino Unido, comumente chamada de monarquia britânica, é a monarquia constitucional do Reino Unido e seus territórios ultramarinos. O título do monarca é "rei" (homem) ou "rainha" (mulher). O atual monarca é Carlos III, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, Isabel II.

O monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o Parlamento e dissolve-lo. Como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro. O monarca é tradicionalmente comandante em chefe das Forças Armadas Britânicas. Apesar da última autoridade formal executiva do governo do Reino Unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.

A monarquia britânica traça suas origens nos pequenos reinos da Escócia na alta idade média e os da Inglaterra anglo-saxã, que consolidaram-se nos reinos da Inglaterra e Escócia por volta do século X. O último monarca anglo-saxão, Haroldo II, foi derrotado e morto em 1066 durante a conquista normanda da Inglaterra e assim a monarquia inglesa passou para o normando Guilherme, o Conquistador, e seus descendentes.

O norte do País de Gales, como principado, virou um estado cliente da Inglaterra no século XIII, enquanto a Magna Carta começou um processo de reduzir os poderes políticos do monarca.

Os reinos da Inglaterra e Escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei Jaime VI da Escócia herdou o trono inglês como Jaime I. De 1649 a 1660, a tradição da monarquia foi quebrada pela republicana Comunidade da Inglaterra, que estabeleceu-se depois da Guerra Civil Inglesa. O Decreto de Estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão. Os reinos da Inglaterra e Escócia foram unidos em 1707 no Reino da Grã-Bretanha, e em 1801 o Reino da Irlanda se uniu para criar o Reino Unido da Grã-Bretanha e Irlanda. O monarca britânico tornou-se o chefe nominal do vasto Império Britânico, que cobriu um quarto da superfície da Terra em sua maior extensão no ano de 1921.

A maior parte da Irlanda separou-se da união na década de 1920 como o Estado Livre Irlandês, com a Declaração Balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro Commonwealth. Depois da Segunda Guerra Mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império. Jorge VI e sua sucessora Isabel II adotaram o título de Chefe da Comunidade Britânica como símbolo da livre associação de estados independentes.

O Reino Unido e quinze outras monarquias da Commonwealth partilham a mesma pessoa como seu monarca e são chamados de Reinos da Comunidade de Nações. Os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino."""

# %%
text = text.lower()
text
# Out:
# 'a monarquia do reino unido, comumente chamada de monarquia britânica, é a monarquia constitucional do reino unido e seus territórios ultramarinos. o título do monarca é "rei" (homem) ou "rainha" (mulher). o atual monarca é carlos iii, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, isabel ii.\n\no monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o parlamento e dissolve-lo. como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro. o monarca é tradicionalmente comandante em chefe das forças armadas britânicas. apesar da última autoridade formal executiva do governo do reino unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.\n\na monarquia britânica traça suas origens nos pequenos reinos da escócia na alta idade média e os da inglaterra anglo-saxã, que consolidaram-se nos reinos da inglaterra e escócia por volta do século x. o último monarca anglo-saxão, haroldo ii, foi derrotado e morto em 1066 durante a conquista normanda da inglaterra e assim a monarquia inglesa passou para o normando guilherme, o conquistador, e seus descendentes.\n\no norte do país de gales, como principado, virou um estado cliente da inglaterra no século xiii, enquanto a magna carta começou um processo de reduzir os poderes políticos do monarca.\n\nos reinos da inglaterra e escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei jaime vi da escócia herdou o trono inglês como jaime i. de 1649 a 1660, a tradição da monarquia foi quebrada pela republicana comunidade da inglaterra, que estabeleceu-se depois da guerra civil inglesa. o decreto de estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão. os reinos da inglaterra e escócia foram unidos em 1707 no reino da grã-bretanha, e em 1801 o reino da irlanda se uniu para criar o reino unido da grã-bretanha e irlanda. o monarca britânico tornou-se o chefe nominal do vasto império britânico, que cobriu um quarto da superfície da terra em sua maior extensão no ano de 1921.\n\na maior parte da irlanda separou-se da união na década de 1920 como o estado livre irlandês, com a declaração balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro commonwealth. depois da segunda guerra mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império. jorge vi e sua sucessora isabel ii adotaram o título de chefe da comunidade britânica como símbolo da livre associação de estados independentes.\n\no reino unido e quinze outras monarquias da commonwealth partilham a mesma pessoa como seu monarca e são chamados de reinos da comunidade de nações. os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino.'

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### Agora, vamos remover as stopwords

# %%
sentences = nltk.sent_tokenize(text)

sentences
# Out:
# ['a monarquia do reino unido, comumente chamada de monarquia britânica, é a monarquia constitucional do reino unido e seus territórios ultramarinos.',
#  'o título do monarca é "rei" (homem) ou "rainha" (mulher).',
#  'o atual monarca é carlos iii, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, isabel ii.',
#  'o monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o parlamento e dissolve-lo.',
#  'como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro.',
#  'o monarca é tradicionalmente comandante em chefe das forças armadas britânicas.',
#  'apesar da última autoridade formal executiva do governo do reino unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.',
#  'a monarquia britânica traça suas origens nos pequenos reinos da escócia na alta idade média e os da inglaterra anglo-saxã, que consolidaram-se nos reinos da inglaterra e escócia por volta do século x. o último monarca anglo-saxão, haroldo ii, foi derrotado e morto em 1066 durante a conquista normanda da inglaterra e assim a monarquia inglesa passou para o normando guilherme, o conquistador, e seus descendentes.',
#  'o norte do país de gales, como principado, virou um estado cliente da inglaterra no século xiii, enquanto a magna carta começou um processo de reduzir os poderes políticos do monarca.',
#  'os reinos da inglaterra e escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei jaime vi da escócia herdou o trono inglês como jaime i. de 1649 a 1660, a tradição da monarquia foi quebrada pela republicana comunidade da inglaterra, que estabeleceu-se depois da guerra civil inglesa.',
#  'o decreto de estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão.',
#  'os reinos da inglaterra e escócia foram unidos em 1707 no reino da grã-bretanha, e em 1801 o reino da irlanda se uniu para criar o reino unido da grã-bretanha e irlanda.',
#  'o monarca britânico tornou-se o chefe nominal do vasto império britânico, que cobriu um quarto da superfície da terra em sua maior extensão no ano de 1921.\n\na maior parte da irlanda separou-se da união na década de 1920 como o estado livre irlandês, com a declaração balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro commonwealth.',
#  'depois da segunda guerra mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império.',
#  'jorge vi e sua sucessora isabel ii adotaram o título de chefe da comunidade britânica como símbolo da livre associação de estados independentes.',
#  'o reino unido e quinze outras monarquias da commonwealth partilham a mesma pessoa como seu monarca e são chamados de reinos da comunidade de nações.',
#  'os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino.']

# %%
sentences[5]
# Out:
# 'o monarca é tradicionalmente comandante em chefe das forças armadas britânicas.'

# %%
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

sentences
# Out:
# [['a',
#   'monarquia',
#   'do',
#   'reino',
#   'unido',
#   ',',
#   'comumente',
#   'chamada',
#   'de',
#   'monarquia',
#   'britânica',
#   ',',
#   'é',
#   'a',
#   'monarquia',
#   'constitucional',
#   'do',
#   'reino',
#   'unido',
#   'e',
#   'seus',
#   'territórios',
#   'ultramarinos',
#   '.'],
#  ['o',
#   'título',
#   'do',
#   'monarca',
#   'é',
#   '``',
#   'rei',
#   "''",
#   '(',
#   'homem',
#   ')',
#   'ou',
#   '``',
#   'rainha',
#   "''",
#   '(',
#   'mulher',
#   ')',
#   '.'],
#  ['o',
#   'atual',
#   'monarca',
#   'é',
#   'carlos',
#   'iii',
#   ',',
#   'que',
#   'ascendeu',
#   'ao',
#   'trono',
#   'em',
#   '8',
#   'de',
#   'setembro',
#   'de',
#   '2022',
#   'após',
#   'a',
#   'morte',
#   'da',
#   'rainha',
#   ',',
#   'isabel',
#   'ii',
#   '.'],
#  ['o',
#   'monarca',
#   'e',
#   'sua',
#   'família',
#   'imediata',
#   'realizam',
#   'várias',
#   'funções',
#   'oficiais',
#   ',',
#   'cerimoniais',
#   ',',
#   'diplomáticas',
#   'e',
#   'representativas',
#   'e',
#   'convocar',
#   'o',
#   'parlamento',
#   'e',
#   'dissolve-lo',
#   '.'],
#  ['como',
#   'monarca',
#   'constitucional',
#   ',',
#   'ele',
#   'ou',
#   'ela',
#   'está',
#   'limitado',
#   'a',
#   'funções',
#   'apartidárias',
#   'como',
#   'a',
#   'outorgação',
#   'de',
#   'honras',
#   'e',
#   'nomeação',
#   'do',
#   'primeiro-ministro',
#   '.'],
#  ['o',
#   'monarca',
#   'é',
#   'tradicionalmente',
#   'comandante',
#   'em',
#   'chefe',
#   'das',
#   'forças',
#   'armadas',
#   'britânicas',
#   '.'],
#  ['apesar',
#   'da',
#   'última',
#   'autoridade',
#   'formal',
#   'executiva',
#   'do',
#   'governo',
#   'do',
#   'reino',
#   'unido',
#   'ainda',
#   'ser',
#   'através',
#   'da',
#   'prerrogativa',
#   'real',
#   'do',
#   'monarca',
#   ',',
#   'esses',
#   'poderes',
#   'podem',
#   'ser',
#   'usados',
#   'apenas',
#   'de',
#   'acordo',
#   'com',
#   'as',
#   'leis',
#   'promulgadas',
#   'pelo',
#   'parlamento',
#   'e',
#   ',',
#   'na',
#   'prática',
#   ',',
#   'dentro',
#   'das',
#   'restrições',
#   'de',
#   'convenções',
#   'e',
#   'precedentes',
#   '.'],
#  ['a',
#   'monarquia',
#   'britânica',
#   'traça',
#   'suas',
#   'origens',
#   'nos',
#   'pequenos',
#   'reinos',
#   'da',
#   'escócia',
#   'na',
#   'alta',
#   'idade',
#   'média',
#   'e',
#   'os',
#   'da',
#   'inglaterra',
#   'anglo-saxã',
#   ',',
#   'que',
#   'consolidaram-se',
#   'nos',
#   'reinos',
#   'da',
#   'inglaterra',
#   'e',
#   'escócia',
#   'por',
#   'volta',
#   'do',
#   'século',
#   'x.',
#   'o',
#   'último',
#   'monarca',
#   'anglo-saxão',
#   ',',
#   'haroldo',
#   'ii',
#   ',',
#   'foi',
#   'derrotado',
#   'e',
#   'morto',
#   'em',
#   '1066',
#   'durante',
#   'a',
#   'conquista',
#   'normanda',
#   'da',
#   'inglaterra',
#   'e',
#   'assim',
#   'a',
#   'monarquia',
#   'inglesa',
#   'passou',
#   'para',
#   'o',
#   'normando',
#   'guilherme',
#   ',',
#   'o',
#   'conquistador',
#   ',',
#   'e',
#   'seus',
#   'descendentes',
#   '.'],
#  ['o',
#   'norte',
#   'do',
#   'país',
#   'de',
#   'gales',
#   ',',
#   'como',
#   'principado',
#   ',',
#   'virou',
#   'um',
#   'estado',
#   'cliente',
#   'da',
#   'inglaterra',
#   'no',
#   'século',
#   'xiii',
#   ',',
#   'enquanto',
#   'a',
#   'magna',
#   'carta',
#   'começou',
#   'um',
#   'processo',
#   'de',
#   'reduzir',
#   'os',
#   'poderes',
#   'políticos',
#   'do',
#   'monarca',
#   '.'],
#  ['os',
#   'reinos',
#   'da',
#   'inglaterra',
#   'e',
#   'escócia',
#   'passaram',
#   'a',
#   'ser',
#   'governados',
#   'por',
#   'um',
#   'único',
#   'soberano',
#   'a',
#   'partir',
#   'de',
#   '1603',
#   ',',
#   'quando',
#   'o',
#   'rei',
#   'jaime',
#   'vi',
#   'da',
#   'escócia',
#   'herdou',
#   'o',
#   'trono',
#   'inglês',
#   'como',
#   'jaime',
#   'i.',
#   'de',
#   '1649',
#   'a',
#   '1660',
#   ',',
#   'a',
#   'tradição',
#   'da',
#   'monarquia',
#   'foi',
#   'quebrada',
#   'pela',
#   'republicana',
#   'comunidade',
#   'da',
#   'inglaterra',
#   ',',
#   'que',
#   'estabeleceu-se',
#   'depois',
#   'da',
#   'guerra',
#   'civil',
#   'inglesa',
#   '.'],
#  ['o',
#   'decreto',
#   'de',
#   'estabelecimento',
#   'de',
#   '1701',
#   ',',
#   'que',
#   'ainda',
#   'está',
#   'em',
#   'vigor',
#   ',',
#   'excluiu',
#   'católicos',
#   ',',
#   'ou',
#   'aqueles',
#   'casados',
#   'com',
#   'católicos',
#   ',',
#   'da',
#   'linha',
#   'de',
#   'sucessão',
#   '.'],
#  ['os',
#   'reinos',
#   'da',
#   'inglaterra',
#   'e',
#   'escócia',
#   'foram',
#   'unidos',
#   'em',
#   '1707',
#   'no',
#   'reino',
#   'da',
#   'grã-bretanha',
#   ',',
#   'e',
#   'em',
#   '1801',
#   'o',
#   'reino',
#   'da',
#   'irlanda',
#   'se',
#   'uniu',
#   'para',
#   'criar',
#   'o',
#   'reino',
#   'unido',
#   'da',
#   'grã-bretanha',
#   'e',
#   'irlanda',
#   '.'],
#  ['o',
#   'monarca',
#   'britânico',
#   'tornou-se',
#   'o',
#   'chefe',
#   'nominal',
#   'do',
#   'vasto',
#   'império',
#   'britânico',
#   ',',
#   'que',
#   'cobriu',
#   'um',
#   'quarto',
#   'da',
#   'superfície',
#   'da',
#   'terra',
#   'em',
#   'sua',
#   'maior',
#   'extensão',
#   'no',
#   'ano',
#   'de',
#   '1921.',
#   'a',
#   'maior',
#   'parte',
#   'da',
#   'irlanda',
#   'separou-se',
#   'da',
#   'união',
#   'na',
#   'década',
#   'de',
#   '1920',
#   'como',
#   'o',
#   'estado',
#   'livre',
#   'irlandês',
#   ',',
#   'com',
#   'a',
#   'declaração',
#   'balfour',
#   'reconhecendo',
#   'a',
#   'evolução',
#   'dos',
#   'domínios',
#   'do',
#   'império',
#   'em',
#   'países',
#   'separados',
#   'e',
#   'com',
#   'governos',
#   'próprios',
#   'dentro',
#   'commonwealth',
#   '.'],
#  ['depois',
#   'da',
#   'segunda',
#   'guerra',
#   'mundial',
#   ',',
#   'a',
#   'maioria',
#   'das',
#   'colônias',
#   'e',
#   'territórios',
#   'britânicos',
#   'tornou-se',
#   'independentes',
#   ',',
#   'efetivamente',
#   'encerrando',
#   'o',
#   'império',
#   '.'],
#  ['jorge',
#   'vi',
#   'e',
#   'sua',
#   'sucessora',
#   'isabel',
#   'ii',
#   'adotaram',
#   'o',
#   'título',
#   'de',
#   'chefe',
#   'da',
#   'comunidade',
#   'britânica',
#   'como',
#   'símbolo',
#   'da',
#   'livre',
#   'associação',
#   'de',
#   'estados',
#   'independentes',
#   '.'],
#  ['o',
#   'reino',
#   'unido',
#   'e',
#   'quinze',
#   'outras',
#   'monarquias',
#   'da',
#   'commonwealth',
#   'partilham',
#   'a',
#   'mesma',
#   'pessoa',
#   'como',
#   'seu',
#   'monarca',
#   'e',
#   'são',
#   'chamados',
#   'de',
#   'reinos',
#   'da',
#   'comunidade',
#   'de',
#   'nações',
#   '.'],
#  ['os',
#   'termos',
#   '``',
#   'monarquia',
#   'britânica',
#   "''",
#   'e',
#   '``',
#   'monarca',
#   'britânico',
#   "''",
#   'são',
#   'frequentemente',
#   'empregados',
#   'em',
#   'referência',
#   'à',
#   'pessoa',
#   'ou',
#   'à',
#   'instituição',
#   ';',
#   'entretanto',
#   ',',
#   'cada',
#   'país',
#   'é',
#   'soberano',
#   'e',
#   'independente',
#   'do',
#   'outro',
#   ',',
#   'com',
#   'o',
#   'monarca',
#   'tendo',
#   'um',
#   'título',
#   'e',
#   'estilo',
#   'específico',
#   'e',
#   'nacional',
#   'em',
#   'cada',
#   'reino',
#   '.']]

# %%
sentences[5]
# Out:
# ['o',
#  'monarca',
#  'é',
#  'tradicionalmente',
#  'comandante',
#  'em',
#  'chefe',
#  'das',
#  'forças',
#  'armadas',
#  'britânicas',
#  '.']

# %%
sentences[5][1]
# Out:
# 'monarca'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# stopwords
stopwords.words('Portuguese')
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
# remoção das stopwords


for i in range(len(sentences)):
    empty_sentence = []
    for word in sentences[i]:
        if word not in stopwords.words('Portuguese'):
            empty_sentence.append(word)
        sentences[i] = empty_sentence

# %%
sentences
# Out:
# [['monarquia',
#   'reino',
#   'unido',
#   ',',
#   'comumente',
#   'chamada',
#   'monarquia',
#   'britânica',
#   ',',
#   'monarquia',
#   'constitucional',
#   'reino',
#   'unido',
#   'territórios',
#   'ultramarinos',
#   '.'],
#  ['título',
#   'monarca',
#   '``',
#   'rei',
#   "''",
#   '(',
#   'homem',
#   ')',
#   '``',
#   'rainha',
#   "''",
#   '(',
#   'mulher',
#   ')',
#   '.'],
#  ['atual',
#   'monarca',
#   'carlos',
#   'iii',
#   ',',
#   'ascendeu',
#   'trono',
#   '8',
#   'setembro',
#   '2022',
#   'após',
#   'morte',
#   'rainha',
#   ',',
#   'isabel',
#   'ii',
#   '.'],
#  ['monarca',
#   'família',
#   'imediata',
#   'realizam',
#   'várias',
#   'funções',
#   'oficiais',
#   ',',
#   'cerimoniais',
#   ',',
#   'diplomáticas',
#   'representativas',
#   'convocar',
#   'parlamento',
#   'dissolve-lo',
#   '.'],
#  ['monarca',
#   'constitucional',
#   ',',
#   'limitado',
#   'funções',
#   'apartidárias',
#   'outorgação',
#   'honras',
#   'nomeação',
#   'primeiro-ministro',
#   '.'],
#  ['monarca',
#   'tradicionalmente',
#   'comandante',
#   'chefe',
#   'forças',
#   'armadas',
#   'britânicas',
#   '.'],
#  ['apesar',
#   'última',
#   'autoridade',
#   'formal',
#   'executiva',
#   'governo',
#   'reino',
#   'unido',
#   'ainda',
#   'através',
#   'prerrogativa',
#   'real',
#   'monarca',
#   ',',
#   'poderes',
#   'podem',
#   'usados',
#   'apenas',
#   'acordo',
#   'leis',
#   'promulgadas',
#   'parlamento',
#   ',',
#   'prática',
#   ',',
#   'dentro',
#   'restrições',
#   'convenções',
#   'precedentes',
#   '.'],
#  ['monarquia',
#   'britânica',
#   'traça',
#   'origens',
#   'pequenos',
#   'reinos',
#   'escócia',
#   'alta',
#   'idade',
#   'média',
#   'inglaterra',
#   'anglo-saxã',
#   ',',
#   'consolidaram-se',
#   'reinos',
#   'inglaterra',
#   'escócia',
#   'volta',
#   'século',
#   'x.',
#   'último',
#   'monarca',
#   'anglo-saxão',
#   ',',
#   'haroldo',
#   'ii',
#   ',',
#   'derrotado',
#   'morto',
#   '1066',
#   'durante',
#   'conquista',
#   'normanda',
#   'inglaterra',
#   'assim',
#   'monarquia',
#   'inglesa',
#   'passou',
#   'normando',
#   'guilherme',
#   ',',
#   'conquistador',
#   ',',
#   'descendentes',
#   '.'],
#  ['norte',
#   'país',
#   'gales',
#   ',',
#   'principado',
#   ',',
#   'virou',
#   'estado',
#   'cliente',
#   'inglaterra',
#   'século',
#   'xiii',
#   ',',
#   'enquanto',
#   'magna',
#   'carta',
#   'começou',
#   'processo',
#   'reduzir',
#   'poderes',
#   'políticos',
#   'monarca',
#   '.'],
#  ['reinos',
#   'inglaterra',
#   'escócia',
#   'passaram',
#   'governados',
#   'único',
#   'soberano',
#   'partir',
#   '1603',
#   ',',
#   'rei',
#   'jaime',
#   'vi',
#   'escócia',
#   'herdou',
#   'trono',
#   'inglês',
#   'jaime',
#   'i.',
#   '1649',
#   '1660',
#   ',',
#   'tradição',
#   'monarquia',
#   'quebrada',
#   'republicana',
#   'comunidade',
#   'inglaterra',
#   ',',
#   'estabeleceu-se',
#   'guerra',
#   'civil',
#   'inglesa',
#   '.'],
#  ['decreto',
#   'estabelecimento',
#   '1701',
#   ',',
#   'ainda',
#   'vigor',
#   ',',
#   'excluiu',
#   'católicos',
#   ',',
#   'casados',
#   'católicos',
#   ',',
#   'linha',
#   'sucessão',
#   '.'],
#  ['reinos',
#   'inglaterra',
#   'escócia',
#   'unidos',
#   '1707',
#   'reino',
#   'grã-bretanha',
#   ',',
#   '1801',
#   'reino',
#   'irlanda',
#   'uniu',
#   'criar',
#   'reino',
#   'unido',
#   'grã-bretanha',
#   'irlanda',
#   '.'],
#  ['monarca',
#   'britânico',
#   'tornou-se',
#   'chefe',
#   'nominal',
#   'vasto',
#   'império',
#   'britânico',
#   ',',
#   'cobriu',
#   'quarto',
#   'superfície',
#   'terra',
#   'maior',
#   'extensão',
#   'ano',
#   '1921.',
#   'maior',
#   'parte',
#   'irlanda',
#   'separou-se',
#   'união',
#   'década',
#   '1920',
#   'estado',
#   'livre',
#   'irlandês',
#   ',',
#   'declaração',
#   'balfour',
#   'reconhecendo',
#   'evolução',
#   'domínios',
#   'império',
#   'países',
#   'separados',
#   'governos',
#   'próprios',
#   'dentro',
#   'commonwealth',
#   '.'],
#  ['segunda',
#   'guerra',
#   'mundial',
#   ',',
#   'maioria',
#   'colônias',
#   'territórios',
#   'britânicos',
#   'tornou-se',
#   'independentes',
#   ',',
#   'efetivamente',
#   'encerrando',
#   'império',
#   '.'],
#  ['jorge',
#   'vi',
#   'sucessora',
#   'isabel',
#   'ii',
#   'adotaram',
#   'título',
#   'chefe',
#   'comunidade',
#   'britânica',
#   'símbolo',
#   'livre',
#   'associação',
#   'estados',
#   'independentes',
#   '.'],
#  ['reino',
#   'unido',
#   'quinze',
#   'outras',
#   'monarquias',
#   'commonwealth',
#   'partilham',
#   'mesma',
#   'pessoa',
#   'monarca',
#   'chamados',
#   'reinos',
#   'comunidade',
#   'nações',
#   '.'],
#  ['termos',
#   '``',
#   'monarquia',
#   'britânica',
#   "''",
#   '``',
#   'monarca',
#   'britânico',
#   "''",
#   'frequentemente',
#   'empregados',
#   'referência',
#   'pessoa',
#   'instituição',
#   ';',
#   'entretanto',
#   ',',
#   'cada',
#   'país',
#   'soberano',
#   'independente',
#   'outro',
#   ',',
#   'monarca',
#   'tendo',
#   'título',
#   'estilo',
#   'específico',
#   'nacional',
#   'cada',
#   'reino',
#   '.']]

# %% [markdown]
# #### Agora, vamos utilizar o Word2Vec para encontrar palavras similares!

# %%
model = Word2Vec(sentences, min_count=1)

words_vector = model.wv

# %%
words_vector.most_similar("monarca")
# Out:
# [('volta', 0.37331992387771606),
#  ('inglesa', 0.2129473090171814),
#  ('encerrando', 0.20699244737625122),
#  ('reinos', 0.20354725420475006),
#  ('origens', 0.20350506901741028),
#  ('superfície', 0.1995421051979065),
#  ('ano', 0.1994330883026123),
#  ('inglês', 0.194091796875),
#  ('várias', 0.18930427730083466),
#  ('i.', 0.18772007524967194)]

# %%
words_vector.most_similar("reino")
# Out:
# [('1801', 0.2967849373817444),
#  ('quinze', 0.2726386487483978),
#  ('países', 0.25665926933288574),
#  ('outro', 0.22230902314186096),
#  ('específico', 0.2156076729297638),
#  ('derrotado', 0.2047862708568573),
#  ('após', 0.18256120383739471),
#  ('chefe', 0.1781557947397232),
#  ('passaram', 0.16451191902160645),
#  ('x.', 0.16397054493427277)]

# %%
words_vector.most_similar("rei")
# Out:
# [('escócia', 0.32014861702919006),
#  ('estilo', 0.2513645887374878),
#  ('poderes', 0.18950152397155762),
#  ('instituição', 0.16134604811668396),
#  ('chefe', 0.16051112115383148),
#  ('precedentes', 0.1460183560848236),
#  ('irlandês', 0.14394345879554749),
#  ('enquanto', 0.13704730570316315),
#  ('executiva', 0.13270370662212372),
#  ('imediata', 0.13162848353385925)]
